# %% [markdown]
# # Wage: Mid-Atlantic Wage Data

# %% [markdown]
# ### Research Question:
# What factors best predict an individual’s wage using the `Wage` dataset?

# %%
import pandas as pyimport 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
# %matplotlib inline

# %% [markdown]
# ## Check wage dataset

# %%
#convert csv file to panda dataframe and dictionary
wage_df = pd.read_csv('wage.csv')
wage_data = wage_df.to_dict()

# %%
#check on first 10 ID
wage_df.head(10)
# Out:
#    Unnamed: 0  year  age            maritl      race        education  \
# 0      231655  2006   18  1. Never Married  1. White     1. < HS Grad
# 1       86582  2004   24  1. Never Married  1. White  4. College Grad
# 2      161300  2003   45        2. Married  1. White  3. Some College
# 3      155159  2003   43        2. Married  3. Asian  4. College Grad
# 4       11443  2005   50       4. Divorced  1. White       2. HS Grad
# 5      376662  2008   54        2. Married  1. White  4. College Grad
# 6      450601  2009   44        2. Married  4. Other  3. Some College
# 7      377954  2008   30  1. Never Married  3. Asian  3. Some College
# 8      228963  2006   41  1. Never Married  2. Black  3. Some College
# 9       81404  2004   52        2. Married  1. White       2. HS Grad
#
#                region        jobclass          health health_ins   logwage  \
# 0  2. Middle Atlantic   1. Industrial       1. <=Good      2. No  4.318063
# ...

# %%
len(wage_df)
# Out:
# 3000

# %% [markdown]
# ## Data visualization

# %%
#plot histogram chart for continuous variables
continuous_variables =['year','age','logwage','wage']
for i in list(range(0, len(continuous_variables))):
    list_data_for_the_variable = list(wage_data[continuous_variables[i]].values())
    plt.figure(figsize=(8,6))
    plt.title(continuous_variables[i])
    plt.hist(x = list_data_for_the_variable, bins = 5, edgecolor='black')
    plt.xlabel(continuous_variables[i])
    plt.ylabel('frequency')

# %%
#plot histgram chart for categorical variables
categorical_variables =['maritl','race','education','region','jobclass','health','health_ins']
for i in list(range(0, len(categorical_variables))):
    list_values_for_the_variable = list(wage_data[categorical_variables[i]].values())   
    list_keys_for_the_variable = list(wage_data[categorical_variables[i]].keys())
    plt.figure(figsize=(8,6))
    plt.title(categorical_variables[i])
    plt.hist(x = list_values_for_the_variable, bins = 5, edgecolor='black')
    plt.xlabel(categorical_variables[i])
    plt.ylabel('numbers')

# %% [markdown]
# ## Fit with a linear OLS regression model

# %%
#Fit with OLS linear regression model
#model
result = smf.ols('wage ~ year + education + age + race + maritl + region + jobclass + health + health_ins + logwage', data=wage_df).fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   wage   R-squared:                       0.909
# Model:                            OLS   Adj. R-squared:                  0.909
# Method:                 Least Squares   F-statistic:                     1756.
# Date:                Thu, 21 Nov 2019   Prob (F-statistic):               0.00
# Time:                        12:46:40   Log-Likelihood:                -11851.
# No. Observations:                3000   AIC:                         2.374e+04
# Df Residuals:                    2982   BIC:                         2.385e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Visualization of how each variable affacts with wage

# %%
fig = plt.figure(figsize=(20,18))
fig = sm.graphics.plot_partregress_grid(result, fig=fig)

# %% [markdown]
# ### R**2 Value

# %%
print(result1.rsquared)
# Out:
# 0.9091208885000359

# %% [markdown]
# ## Interpretation of standardized and unstandardized coefficients

# %% [markdown]
# As we can see from the output of the result by using OLS Regression model, our unstandardized coefficients shows there's a strong positive relation between education and wage, as the higher education you get, the high wage you will possibly get. Also health_ins has a large impact on wage as well.

# %% [markdown]
# ## Write two lists
# **List of tasks you found easy and hard**

# %% [markdown]
# Easy: Data visualization with matplotlib is relatively more straight-forward then the rest of the tasks.

# %% [markdown]
# Hard:
# - Using statsmodels.api to find the right regression model to fit with our dataset.
# - And luckily the data is pretty clean in this example, I'm not very good at data cleaning so need to find more practice on that issue too.
# - Need to study more on statistics (i.e. standardized vs unstandardized coefficients)
